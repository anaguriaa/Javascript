# %% [markdown]
# <a href="https://colab.research.google.com/github/anaguriaa/Javascript/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *PROJETO REGRESSÃO LINEAR PARA O FLASH
#
#
# # **IMPORTANDO BLIBLIOTECAS**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas  as pd
import numpy as np

# %% [markdown]
# ## BLIBLIOTECAS OPCIONAIS
#
#
# **kaggle site para estudar Análise de Dados **
#
#
# ## ESTIMATIVA DE VENDAS

# %% [markdown]
# **Leitura dos dados **

# %%
dados = pd.read_csv('../08 AGOSTO 2022 (Modelo).csv', sep=';')

# %% [markdown]
# # Visualizar dados

# %%
dados
# Out:
#                Unnamed: 0           Unnamed: 1      Unnamed: 2  \
# 0                 MERCADO             SEGMENTO  CÓDIGO CLIENTE
# 1    V-Glass Refractories      V02-Verre Creux          117594
# 2    V-Glass Refractories      V02-Verre Creux          117594
# 3               I00 - SGP  I04 Alumina Zirc AZ          119788
# 4               I00 - SGP  I04 Alumina Zirc AZ          119788
# ..                    ...                  ...             ...
# 774                   NaN                  NaN             NaN
# 775                   NaN                  NaN             NaN
# 776                   NaN                  NaN             NaN
# 777                   NaN                  NaN             NaN
# 778                   NaN                  NaN             NaN
#
#                            Unnamed: 3   Unnamed: 4  \
# 0                             CLIENTE       CÓDIGO
# 1            OWENS-ILLINOIS DO BRASIL  400.063.059
# 2            OWENS-ILLINOIS DO BRASIL  400.063.059
# ...

# %%
dados.shape
# Out:
# (779, 19)
